# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import re
from selenium.webdriver.support.ui import WebDriverWait as w
from selenium.webdriver.support import expected_conditions as ec
import csv

# %% [markdown]
# ![link](https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fmedia.tenor.com%2Fimages%2Fb14d242b455079a5283836f7a3f84181%2Ftenor.png&f=1&nofb=1)

# %%
col = ['cast', 'line']

with open('entire_script.csv', 'w',encoding="UTF-8", errors = 'ignore') as csvFile:
    writer = csv.writer(csvFile)
    writer.writerow(col)
    

brave_options = webdriver.ChromeOptions()
brave_options.binary_location = 'C:\\Program Files\\BraveSoftware\\Brave-Browser\\Application\\brave.exe'
# Initialize the browser object
driver = driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=brave_options)

# URL to go to
url = "https://fangj.github.io/friends/"
# Maximize the browser window
driver.maximize_window()
# Opens the URL in the browser
driver.get(url)
links = []
for a in driver.find_elements(By.XPATH,'.//a'):    
    links.append(a.get_attribute('href'))
for i in links:
    url = i
    driver.get(url)
    name = driver.find_elements_by_tag_name('p')
    
    for j in name:
        with open('entire_script.csv', 'a', encoding = "UTF-8", errors = 'ignore') as csvFile:
            writer = csv.writer(csvFile)
            writer.writerow(str(j.text).split(':'))
        csvFile.close()
driver.close()
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST chromedriver version for 97.0.4692 google-chrome
# Driver [C:\Users\AB\.wdm\drivers\chromedriver\win32\97.0.4692.71\chromedriver.exe] found in cache
# <ipython-input-93-11d6dd5872f2>:25: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name = driver.find_elements_by_tag_name('p')

# %% [raw]
# brave_options = webdriver.ChromeOptions()
# brave_options.binary_location = 'C:\\Program Files\\BraveSoftware\\Brave-Browser\\Application\\brave.exe'
# # Initialize the browser object
# driver = driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=brave_options)
#
# # URL to go to
# url = "https://fangj.github.io/friends/"
# # Maximize the browser window
# driver.maximize_window()
# # Opens the URL in the browser
# driver.get(url)
# links = []
# for a in driver.find_elements(By.XPATH,'.//a'):
#     links.append(a.get_attribute('href'))
#
# print(links)

# %%
brave_options = webdriver.ChromeOptions()
brave_options.binary_location = 'C:\\Program Files\\BraveSoftware\\Brave-Browser\\Application\\brave.exe'
# Initialize the browser object
driver = driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=brave_options)

# URL to go to
url = "https://fangj.github.io/friends/"
# Maximize the browser window
driver.maximize_window()
# Opens the URL in the browser
driver.get(url)
for a in driver.find_elements(By.XPATH,'.//a'):    
    print(a.get_attribute('href'))
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 97.0.4692
# Get LATEST chromedriver version for 97.0.4692 google-chrome
# Driver [C:\Users\AB\.wdm\drivers\chromedriver\win32\97.0.4692.71\chromedriver.exe] found in cache
# https://fangj.github.io/friends/season/0101.html
# https://fangj.github.io/friends/season/0102.html
# https://fangj.github.io/friends/season/0103.html
# https://fangj.github.io/friends/season/0104.html
# https://fangj.github.io/friends/season/0105.html
# https://fangj.github.io/friends/season/0106.html
# https://fangj.github.io/friends/season/0107.html
# https://fangj.github.io/friends/season/0108.html
# https://fangj.github.io/friends/season/0109.html
# https://fangj.github.io/friends/season/0110.html
# https://fangj.github.io/friends/season/0111.html
# https://fangj.github.io/friends/season/0112.html
# https://fangj.github.io/friends/season/0113.html
# https://fangj.github.io/friends/season/0114.html
# ...

# %% [raw]
# brave_options = webdriver.ChromeOptions()
# brave_options.binary_location = 'C:\\Program Files\\BraveSoftware\\Brave-Browser\\Application\\brave.exe'
# # Initialize the browser object
# driver = driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=brave_options)
#
# # URL to go to
# url = "https://fangj.github.io/friends/"
# # Maximize the browser window
# driver.maximize_window()
# # Opens the URL in the browser
# driver.get(url)
# links = driver.find_elements(By.TAG_NAME,'a')
# print('There are', len(links), 'in this website.')

# %% [raw]
# # brave_options = webdriver.ChromeOptions()
# brave_options.binary_location = 'C:\\Program Files\\BraveSoftware\\Brave-Browser\\Application\\brave.exe'
# # Initialize the browser object
# driver = driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=brave_options)
#
# # URL to go to
# url = "https://fangj.github.io/friends/"
# # Maximize the browser window
# driver.maximize_window()
# # Opens the URL in the browser
# driver.get(url)
# links = []
# for a in driver.find_elements(By.XPATH,'.//a'):
#     links.append(a.get_attribute('href'))
# print(links)
# print(len(links))

# %% [raw]
# col = ['cast', 'line']
#
# with open('entir_script.csv', 'w') as csvFile:
#     writer = csv.writer(csvFile)
#     writer.writerow(col)
#
#
# brave_options = webdriver.ChromeOptions()
# brave_options.binary_location = 'C:\\Program Files\\BraveSoftware\\Brave-Browser\\Application\\brave.exe'
# # Initialize the browser object
# driver = webdriver.Chrome('C:\\Program Files\\Google\Chrome\\chromedriver_win32\\chromedriver.exe', options=brave_options)
#
# # URL to go to
# url = "https://fangj.github.io/friends/"
# # Maximize the browser window
# driver.maximize_window()
# # Opens the URL in the browser
# driver.get(url)
# for a in driver.find_elements_by_xpath('.//a'):
#     driver.get(a.get_attribute('href'))
#
#     driver.maximize_window()
#
#     name = driver.find_elements_by_tag_name('p')
#
#     for i in name:
#         with open('entir_script.csv', 'a') as csvFile:
#             writer = csv.writer(csvFile)
#             writer.writerow(str(i.text).split(':'))
#
# csvFile.close()
#
#
# driver.close()
